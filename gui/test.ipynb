# %%
from typing import Dict, List, Optional
from dataclasses import dataclass
import copy
from file_manager import FileManager
import os
import time
import datetime
import boto3
from ddb_handler import DynamoDBHandler

@dataclass
class NodeInfo:
    name: str
    ip: str
    ibdev: List[str]

# %%
DynamoDBHandler.create_table_if_not_exists("nwcd-l4-v1-nodes", 'node_name')
# Out:
# Creating table nwcd-l4-v1-nodes...
# True

# %%
cluster_name = "nwcd-l4-v1" # os.environ.get('CLUSTER_NAME', 'default-cluster')
ecs_client = boto3.client('ecs')
container_instance_arns = []
paginator = ecs_client.get_paginator('list_container_instances')

for page in paginator.paginate(cluster=cluster_name):
    container_instance_arns.extend(page['containerInstanceArns'])

if container_instance_arns:
    desp_response = ecs_client.describe_container_instances(
            cluster=cluster_name,
            containerInstances=container_instance_arns,
            include=['TAGS']  # Include tags in the response
        )

# %%
aws ecs put-attributes \
    --cluster nwcd-l4-v1 \
    --attributes name=node_name,value=node004,targetId=arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/fc0f7fbdd633481885e154c98213b0f5
# Out:
# ['arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/a27e3327be4e41a99cb39d326f7e2ebc',
#  'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/adb5b3187b22471c8994179b11b1e158',
#  'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/e26b0672b1c149e092d6694f0ba042f1',
#  'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/fc0f7fbdd633481885e154c98213b0f5']

# %%
os.system('''export CLUSTER_NAME="nwcd-gpus-v2"''')
os.system('''export JOB_MANAGE_TABLE="$CLUSTER_NAME-jobs"''')
os.system('''export TASK_MANAGE_TABLE="$CLUSTER_NAME-tasks"''')
os.system('''export NODE_MANAGE_TABLE="$CLUSTER_NAME-nodes"''')


class NodeManager:
    def __init__(self):
        print('Node Manager initiated..')
        self.node_config = FileManager.load_yaml("node_mapping_info.yaml")
        
        # Initialize nodes from config
        self.nodes = {
            name: NodeInfo(
                name=name,
                ip=info['ip'],
                ibdev=info['ibdev']
            )
            for name, info in self.node_config.items()
        }
        
        # Initialize DynamoDB table if needed
        self.table_name = "nwcd-gpus-v2-nodes" #os.environ.get('NODE_MANAGE_TABLE', 'node_status_table')
        print('## start creating table ##')
        self.ddb_initialized = DynamoDBHandler.create_table_if_not_exists(self.table_name, 'node_name')
        
        # Initialize ECS client and sync node status with DDB
        if self.ddb_initialized:
            cluster_name = "nwcd-gpus-v2" # os.environ.get('CLUSTER_NAME', 'default-cluster')
            ecs_client = boto3.client('ecs')
            container_instance_arns = []
            paginator = ecs_client.get_paginator('list_container_instances')

            for page in paginator.paginate(cluster=cluster_name):
                container_instance_arns.extend(page['containerInstanceArns'])

            if container_instance_arns:
                desp_response = ecs_client.describe_container_instances(
                        cluster=cluster_name,
                        containerInstances=container_instance_arns,
                        include=['TAGS']  # Include tags in the response
                    )

                for i, inst_arn in enumerate(container_instance_arns):
                    for attrdict in desp_response['containerInstances'][i]['attributes']:
                        if attrdict['name'] == 'name':
                            node_name = attrdict['value']
                            if node_name in self.nodes:
                                # Use DynamoDBHandler to write item
                                DynamoDBHandler.write_item(
                                    table_name=self.table_name,
                                    item={
                                        'node_name': node_name,
                                        'container_instance_id': inst_arn.split('/')[-1],
                                        'container_instance_arn': inst_arn,
                                        'cluster_name': cluster_name,
                                        'last_status': 'AVAILABLE',
                                        'ip': self.nodes.get(node_name).ip,
                                        'ibdev': self.nodes.get(node_name).ibdev,
                                        'created_at': datetime.datetime.now().isoformat(),
                                        'updated_at': datetime.datetime.now().isoformat()
                                    }
                                )

xx = NodeManager()
# Out:
# Node Manager initiated..
# ## start creating table ##
# Table nwcd-gpus-v2-nodes already exists

# %%
from ddb_handler import DynamoDBHandler
DynamoDBHandler.scan_table("nwcd-l4-v1-nodes")
# Out:
# [{'updated_at': '2025-03-06T07:59:26.112900',
#   'ibdev': ['mlx5_10', 'mlx5_11', 'mlx5_12', 'mlx5_13'],
#   'created_at': '2025-03-06T05:13:25.725112',
#   'cluster_name': 'nwcd-l4-v1',
#   'container_instance_arn': 'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/fc0f7fbdd633481885e154c98213b0f5',
#   'ip': '10.11.141.120',
#   'container_instance_id': 'fc0f7fbdd633481885e154c98213b0f5',
#   'node_name': 'node004',
#   'last_status': 'AVAILABLE'},
#  {'updated_at': '2025-03-06T07:59:26.183550',
#   'ibdev': ['mlx5_10', 'mlx5_11', 'mlx5_12', 'mlx5_13'],
#   'created_at': '2025-03-06T05:13:25.593195',
#   'cluster_name': 'nwcd-l4-v1',
#   'container_instance_arn': 'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/e26b0672b1c149e092d6694f0ba042f1',
#   'ip': '10.11.133.25',
#   'container_instance_id': 'e26b0672b1c149e092d6694f0ba042f1',
#   'node_name': 'node003',
#   'last_status': 'AVAILABLE'},
#  {'updated_at': '2025-03-06T08:02:37.913181',
#   'ibdev': ['mlx5_10', 'mlx5_11', 'mlx5_12', 'mlx5_13'],
#   'created_at': '2025-03-06T05:13:25.335928',
#   'cluster_name': 'nwcd-l4-v1',
#   'container_instance_arn': 'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/a27e3327be4e41a99cb39d326f7e2ebc',
#   'ip': '10.11.138.138',
#   'container_instance_id': 'a27e3327be4e41a99cb39d326f7e2ebc',
#   'node_name': 'node001',
#   'last_status': 'AVAILABLE'},
#  {'updated_at': '2025-03-06T08:02:37.383853',
#   'ibdev': ['mlx5_10', 'mlx5_11', 'mlx5_12', 'mlx5_13'],
#   'created_at': '2025-03-06T05:13:25.472143',
#   'cluster_name': 'nwcd-l4-v1',
#   'container_instance_arn': 'arn:aws:ecs:us-east-1:633205212955:container-instance/nwcd-l4-v1/adb5b3187b22471c8994179b11b1e158',
#   'ip': '10.11.134.250',
#   'container_instance_id': 'adb5b3187b22471c8994179b11b1e158',
#   'node_name': 'node002',
#   'last_status': 'AVAILABLE'}]

# %%
from ddb_handler import DynamoDBHandler
DynamoDBHandler.scan_table("nwcd-l4-v1-jobs")
# Out:
# [{'updated_at': '2025-03-06T07:54:48.071986',
#   'assigned_nodes': ['node003', 'node004'],
#   'created_at': '2025-03-06T07:54:48.071994',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['ff0e11f17cd7440f967dc2d1f923d0bc',
#    'd101c24b45a0402bbcc640cae81d74fd'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-075445',
#   'submittd_container_inst_ids': ['e26b0672b1c149e092d6694f0ba042f1',
#    'fc0f7fbdd633481885e154c98213b0f5'],
#   'job_id': 'job1-20250306-075445-158e4cae',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T07:39:52.655532',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T07:39:52.655545',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['e80093343bd64dfabda415662e498387',
#    '99a00fb5992a4af3980a3e8993092aea'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-073949',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-073949-8a97b533',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T06:59:50.758336',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T06:59:50.758344',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['1fb0cbce299e412691e1acf554d3e77f',
#    '76b89b18c17c44bc9018974e15c5bd00'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-065947',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job2-20250306-065947-bfdb526d',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T08:20:20.291914',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T08:20:20.291922',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['8cd1635ca4d041d8aecb64e05dc3b20e',
#    '86815022646a4ea58c7b9dc8e18036ea'],
#   'num_nodes': Decimal('2'),
#   'job_timestamp': '20250306-082017',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-082017-30b394f5',
#   'retry': Decimal('0'),
#   'job_status': 'IN_PROGRESS'},
#  {'assigned_nodes': ['node003', 'node004'],
#   'created_at': '2025-03-06T05:42:30.188880',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['18539c737d3a48b8ab291031ee80e030',
#    'd27a7785848343b0b8938633f12a91e2'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-054227',
#   'submittd_container_inst_ids': ['e26b0672b1c149e092d6694f0ba042f1',
#    'fc0f7fbdd633481885e154c98213b0f5'],
#   'job_id': 'job1-20250306-054227-f0f69662',
#   'retry': Decimal('0')},
#  {'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T05:59:24.932787',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['0ed7c997984a4f508dc9b08a67656876',
#    'fb7e444034e94e4c886e071c6fd0f385'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-055922',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-055922-952fd5ee',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T08:21:37.518399',
#   'assigned_nodes': ['node003', 'node004'],
#   'created_at': '2025-03-06T08:21:37.518407',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['a36671211a60465da507fd2555301f82',
#    '3f2bf95c26e84abea313734b6d9e3ee8'],
#   'num_nodes': Decimal('2'),
#   'job_timestamp': '20250306-082133',
#   'submittd_container_inst_ids': ['e26b0672b1c149e092d6694f0ba042f1',
#    'fc0f7fbdd633481885e154c98213b0f5'],
#   'job_id': 'job1-20250306-082133-ac89ee5b',
#   'retry': Decimal('0'),
#   'job_status': 'IN_PROGRESS'},
#  {'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T05:53:31.394963',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['c30be95324ee4296bd84a981c59ca3c3',
#    '1b60ba8280ab42bfa9295a19afd6167f'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-055328',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-055328-1d197cf2',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T07:59:30.990684',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T07:59:30.990694',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['25aa673d7b924c8eb44637a18a84e92f',
#    'aeb7bd76ae104837b2d7e2b01d7bdc79'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-075928',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-075928-9b5ed02a',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T08:01:24.089932',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T08:01:24.089944',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['da31c3194df747a09cfe70d094ef8eee',
#    '2526374ed1ed4d4296aa20135ee2a3f8'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-080121',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-080121-5c33e936',
#   'retry': Decimal('0')},
#  {'assigned_nodes': ['node001'],
#   'created_at': '2025-03-06T05:31:47.721182',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['0e5e0c0e9662429fb7520f5c0fdc3086'],
#   'num_nodes': Decimal('1'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-053146',
#   'submittd_container_inst_ids': ['a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-053146-63fbc1ea',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T06:59:28.451044',
#   'assigned_nodes': ['node003', 'node004'],
#   'created_at': '2025-03-06T06:59:28.451054',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['f3753db1a3aa4746a2c26fb85509e57e',
#    'dc97afabba8f42e795cb41f819a9de72'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-065925',
#   'submittd_container_inst_ids': ['e26b0672b1c149e092d6694f0ba042f1',
#    'fc0f7fbdd633481885e154c98213b0f5'],
#   'job_id': 'job1-20250306-065925-c64554b6',
#   'retry': Decimal('0')},
#  {'assigned_nodes': ['node002'],
#   'created_at': '2025-03-06T05:15:37.494643',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['55b3a30fb0864b899ce3fda748adf600'],
#   'num_nodes': Decimal('1'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-051536',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158'],
#   'job_id': 'job1-20250306-051536-6eb0c5d0',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T07:40:50.186647',
#   'assigned_nodes': ['node003', 'node004'],
#   'created_at': '2025-03-06T07:40:50.186655',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['1569acce822a4178b0e2a76bd8b7bd5b',
#    '1b67ca6f9895405d84b13120fc86905e'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-074047',
#   'submittd_container_inst_ids': ['e26b0672b1c149e092d6694f0ba042f1',
#    'fc0f7fbdd633481885e154c98213b0f5'],
#   'job_id': 'job12-20250306-074047-f5efd2d8',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T07:52:36.177090',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T07:52:36.177098',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['ac1f87bd70ac4119aad75978e5a01d29',
#    'bffb1c83b97a442f9b37ba6bd0a0ac7e'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-075233',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-075233-777ceccd',
#   'retry': Decimal('0')},
#  {'updated_at': '2025-03-06T08:17:32.372036',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T08:17:32.372044',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['ca7ba2998b494fdabbca039d41b318ca',
#    '77481699cd3f4e499ca285c78d09523a'],
#   'num_nodes': Decimal('2'),
#   'job_timestamp': '20250306-081729',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-081729-579fe6c1',
#   'retry': Decimal('0'),
#   'job_status': 'IN_PROGRESS'},
#  {'updated_at': '2025-03-06T07:46:20.984427',
#   'assigned_nodes': ['node002', 'node001'],
#   'created_at': '2025-03-06T07:46:20.984436',
#   'cluster_name': 'nwcd-l4-v1',
#   'submittd_ecs_task_ids': ['a73d389e875044699cbdbf79c627de34',
#    '5f88f5e201de496eac9225364a0c62e2'],
#   'num_nodes': Decimal('2'),
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-074618',
#   'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#    'a27e3327be4e41a99cb39d326f7e2ebc'],
#   'job_id': 'job1-20250306-074618-6f3bc476',
#   'retry': Decimal('0')}]

# %%
from ddb_handler import DynamoDBHandler
DynamoDBHandler.scan_table("nwcd-l4-v1-tasks")
# Out:
# [{'task_def_revision': '18',
#   'created_at': '2025-03-06T03:12:43.663541',
#   'cluster_name': 'nwcd-gpus-v2',
#   'status': 'IN_PROGRESS',
#   'job_timestamp': '20250306-031242',
#   'ecs_task_id': '4c27005017904caa8bb33e9deaad28a8',
#   'job_id': 'job1-20250306-031242-dd271b89',
#   'node_name': 'node003',
#   'retry': Decimal('0'),
#   'task_def_arn': 'ECSTrainingJob-job1:18',
#   'updated_at': '2025-03-06T03:12:43.663531',
#   'container_inst_id': 'b5fcea53241b4d30aeaf6c9f6287b580',
#   'node_index_in_job': Decimal('0'),
#   'task_def_name': 'ECSTrainingJob-job1',
#   'job_num_nodes': Decimal('1')}]

# %%
dynamodb = boto3.resource('dynamodb')
resp = DynamoDBHandler.get_item('nwcd-l4-v1-jobs', {'job_id':'job1-20250306-080121-5c33e936'})
# resp['submittd_ecs_task_ids']
resp
# Out:
# {'updated_at': '2025-03-06T08:01:24.089932',
#  'assigned_nodes': ['node002', 'node001'],
#  'created_at': '2025-03-06T08:01:24.089944',
#  'cluster_name': 'nwcd-l4-v1',
#  'submittd_ecs_task_ids': ['da31c3194df747a09cfe70d094ef8eee',
#   '2526374ed1ed4d4296aa20135ee2a3f8'],
#  'num_nodes': Decimal('2'),
#  'status': 'IN_PROGRESS',
#  'job_timestamp': '20250306-080121',
#  'submittd_container_inst_ids': ['adb5b3187b22471c8994179b11b1e158',
#   'a27e3327be4e41a99cb39d326f7e2ebc'],
#  'job_id': 'job1-20250306-080121-5c33e936',
#  'retry': Decimal('0')}

# %%
from datetime import datetime
success = DynamoDBHandler.update_item(
            table_name='nwcd-l4-v1-jobs', 
            key={'job_id': 'job1-20250306-082133-ac89ee5b'},
            update_expression="SET job_status = :s, updated_at = :t",
            expression_values={
                ':s': 'USER_STOPPED',
                ':t': datetime.now().isoformat()
            }
        )
